# %% [markdown]
# ## Задание 1.
#
#
# Написать алгоритм получения данных по вакансиям для IT-специалистов с одного из работных сайтов.
#
#
#
# Алгоритм позволяет получить информацию о количестве вакансий по направлениям Data Analyst, Data Science и Data Engineer в разрезе уровней (Junior, Middle, Senior).
#
#
# За основу можно взять как один регион (НН, Москва и т.д.)  так и несколько.
#
#
# Результат представить в табличном и/или графическом виде.

# %%
import requests

url = "https://api.hh.ru/areas"

response = requests.get(url)
areas = response.json()

# %%
def get_areas_recursive(areas):
    all_areas = {}
    for area in areas:
        all_areas[area.get("name")] = area.get("id")
        if area.get("areas"):
            all_areas.update(get_areas_recursive(area.get("areas")))
    return all_areas


all_areas = get_areas_recursive(areas)

# %%
import ipywidgets as widgets
from IPython.display import display

areas_names = list(all_areas.keys())

city_combobox = widgets.Combobox(
    placeholder='Выберите город',
    options=areas_names,
    description='Город:',
    ensure_option=True,
    disabled=False
)

display(city_combobox)
# Out:
# Combobox(value='', description='Город:', ensure_option=True, options=('Россия', 'Республика Марий Эл', 'Вилова…

# %%
areas_names
# Out:
# ['Россия',
#  'Республика Марий Эл',
#  'Виловатово',
#  'Волжск',
#  'Звенигово',
#  'Знаменский',
#  'Йошкар-Ола',
#  'Кельмаксола',
#  'Килемары',
#  'Козьмодемьянск',
#  'Красногорский (Республика Марий Эл)',
#  'Краснооктябрьский',
#  'Красный Стекловар',
#  'Куженер',
#  'Кузнецово',
#  'Мариец',
#  'Мари-Турек',
#  'Медведево',
#  'Михайловка (Республика Марий Эл)',
#  'Морки',
#  'Мочалище',
#  'Новый Торъял',
#  'Оршанка',
#  'Параньга',
#  'Пектубаево',
#  'Приволжский (Республика Марий Эл)',
#  'Семеновка (Республика Марий Эл)',
#  'Сернур',
#  'Советский (Республика Марий Эл)',
#  'Сотнур',
#  'Сурок',
#  'Суслонгер',
#  'Юрино',
#  'Силикатный',
#  'Республика Татарстан',
#  'Агрыз',
#  'Азнакаево',
#  'Айша',
#  'Аккузово',
#  'Аксубаево',
#  'Актаныш',
#  'Актюбинский',
#  'Алексеевское',
#  'Альметьевск',
#  'Апазово',
#  'Апастово',
#  'Арск',
#  'Асеево',
#  'Атабаево',
#  'Аю',
#  'Бавлы',
#  'Базарные Матаки',
#  'Байряка',
#  'Балтаси',
#  'Бетьки',
#  'Биклянь',
#  'Биляр-Озеро',
#  'Билярск',
#  'Богатые Сабы',
#  'Болгар',
#  'Большая Атня',
#  'Большая Турма',
#  'Большие Кайбицы',
#  'Большие Ключи',
#  'Большие Тарханы',
#  'Большое Афанасово',
#  'Большое Нуркеево',
#  'Большое Подберезье',
#  'Большое Шемякино',
#  'Большой Сухояш',
#  'Большой Чекмак',
#  'Бугульма',
#  'Буинск',
#  'Бураково',
#  'Бухарай',
#  'Васильево',
#  'Верхние Челны',
#  'Верхний Такермен',
#  'Верхний Услон',
#  'Высокая Гора',
#  'Габишево',
#  'Деушево',
#  'Джалиль',
#  'Дубъязы',
#  'Елабуга',
#  'Елантово',
#  'Елаур',
#  'Елхово',
#  'Ерыкла',
#  'Жуково',
#  'Заинск',
#  'Зай-Каратай',
#  'Зеленая Роща',
#  'Зеленодольск (Республика Татарстан)',
#  'Именьково',
#  'Юлтимерово',
#  'Иннополис',
#  'Исенбаево',
#  'Иске-Рязап',
#  'Кадыбаш',
#  'Кадырово',
#  'Каенлы',
#  'Казань',
#  'Какре-Елга',
#  'Калмаш',
#  'Камские Поляны',
#  'Камский Леспромхоз',
#  'Камское Устье',
#  'Карабаш (Республика Татарстан)',
#  'Караталга',
#  'Каргали',
#  'Каркаусь',
#  'Кармалы',
#  'Кият',
#  'Кляшево',
#  'Коноваловка',
#  'Кощаково',
#  'Красный Бор (Республика Татарстан)',
#  'Красный Ключ',
#  'Кряш-Шуран',
#  'Кузембетьево',
#  'Куйбышевский Затон',
#  'Кукмор',
#  'Кулаево',
#  'Куркачи',
#  'Кутемели',
#  'Кутлу-Букаш',
#  'Куюки',
#  'Лаишево',
#  'Лениногорск',
#  'Ленино-Кокушкино',
#  'Лубяны',
#  'Мактама',
#  'Макулово',
#  'Малая Елга',
#  'Малая Шильна',
#  'Малые Меми',
#  'Мамадыш',
#  'Мамыково',
#  'Менделеевск',
#  'Мензелинск',
#  'Мокрые Курнали',
#  'Муртыш-Тамак',
#  'Муслюмово',
#  'Мюд',
#  'Набережные Челны',
#  'Нармонка',
#  'Нижнее Алькеево',
#  'Нижнекамск',
#  'Нижние Аты',
#  'Нижние Вязовые',
#  'Нижний Каракитан',
#  'Нижний Таканыш',
#  'Нижняя Мактама',
#  'Новое Ибрайкино',
#  'Новое Каширово',
#  'Новое Шигалиево',
#  'Новошешминск',
#  'Новый Кинер',
#  'Нурлат',
#  'Нурлаты',
#  'Октябрьский (Республика Татарстан)',
#  'Осиново',
#  'Пестрецы',
#  'Песчаные Ковали',
#  'Петровский Завод',
#  'Победа',
#  'Поисево',
#  'Поселок Бирюлинского Зверосовхоза',
#  'Поселок станции Каратун',
#  'Русский Акташ',
#  'Рыбная Слобода',
#  'Саклов-Баш',
#  'Сарманово',
#  'Сатламышево',
#  'Светлое Озеро',
#  'Совхоз Татарстан',
#  'Сокуры',
#  'Старое Альметьево',
#  'Старое Дрожжаное',
#  'Старое Сафарово',
#  'Старое Шаймурзино',
#  'Старошешминск',
#  'Старые Бугады',
#  'Старые Карамалы',
#  'Старые Челны',
#  'Старый Кашир',
#  'Старый Кувак',
#  'Старый Юраш',
#  'Столбище',
#  'Сулеево',
#  'Такталачук',
#  'Татарские Суксы',
#  'Татарские Ямалы',
#  'Татарский Сарсаз',
#  'Татарское Адельшино',
#  'Тенишево',
#  'Теньки',
#  'Терси',
#  'Тетюши',
#  'Тлянче-Тамак',
#  'Тумутук',
#  'Тюлячи',
#  'Тюрнясево',
#  'Убей',
#  'Урняк',
#  'Уруссу',
#  'Урюм',
#  'Усады',
#  'Учалле',
#  'Хозесаново',
#  'Ципья',
#  'Чалпы',
#  'Чепчуги',
#  'Черемшан',
#  'Чистополь',
#  'Чувашское Дрожжаное',
#  'Чэчэкле',
#  'Шапши',
#  'Шеланга',
#  'Шемордан',
#  'Шереметьевка',
#  'Шингальчи',
#  'Шипки',
#  'Шушмабаш',
#  'Ютаза',
#  'Юхмачи',
#  'Удмуртская Республика',
#  'Алнаши',
#  'Арзамасцево',
#  'Бабино',
#  'Балезино',
#  'Балезино-3',
#  'Большая Уча',
#  'Большое Волково',
#  'Большой Зетым',
#  'Булай',
#  'Вавож',
#  'Водзимонье',
#  'Воткинск',
#  'Глазов',
#  'Грахово',
#  'Дебёсы',
#  'Дизьмино',
#  'Ершовка',
#  'Завьялово',
#  'Засеково',
#  'Зура',
#  'Игра',
#  'Ижевск',
#  'Июльское',
#  'Какмож',
#  'Кама',
#  'Камбарка',
#  'Камское',
#  'Каракулино',
#  'Каркалай',
#  'Карсовай',
#  'Кварса',
#  'Кватчи',
#  'Кез',
#  'Кигбаево',
#  'Кизнер',
#  'Кильмезь',
#  'Киясово',
#  'Красногорское',
#  'Кулига',
#  'Кыйлуд',
#  'Лынга',
#  'Мазунино',
#  'Малая Пурга',
#  'Менил',
#  'Можга',
#  'Мукши',
#  'Нечкино',
#  'Новая Бия',
#  'Новый Мултан',
#  'Нылга',
#  'Нюрдор-Котья',
#  'Октябрьский (Удмуртская Республика)',
#  'Орловское',
#  'Пирогово',
#  'Подшивалово',
#  'Понино',
#  'Пугачево',
#  'Пудем',
#  'Пычас',
#  'Рябово (Удмуртская Республика)',
#  'Уральский (Удмуртская Республика)',
#  'Сарапул',
#  'Селты',
#  'Сигаево',
#  'Старые Зятцы',
#  'Старые Какси',
#  'Сюмси',
#  'Тарасово',
#  'Ува',
#  'Удугучин',
#  'Укан',
#  'Факел',
#  'Хохряки',
#  'Чепца',
#  'Чур',
#  'Чутырь',
#  'Шаркан',
#  'Юкаменское',
#  'Яган-Докья',
#  'Якшур',
#  'Якшур-Бодья',
#  'Яр',
#  'Чувашская Республика',
#  'Айбечи',
#  'Аксарино',
#  'Алатырь',
#  'Аликово',
#  'Алманчиково',
#  'Алтышево',
#  'Анастасово',
#  'Анаткасы',
#  'Атнары',
#  'Атрать',
#  'Батырево',
#  'Бичурга-Баишево',
#  'Богатырево',
#  'Большая Выла',
#  'Большие Алгаши',
#  'Большие Катраси',
#  'Большие Яуши',
#  'Большое Шигаево',
#  'Большое Яниково',
#  'Большой Сундырь',
#  'Верхние Ачаки',
#  'Вурнары',
#  'Вутабоси',
#  'Егоркино',
#  'Еметкино',
#  'Ермошкино',
#  'Ибреси',
#  'Иваньково-Ленино',
#  'Испуханы',
#  'Ишаки',
#  'Ишлеи',
#  'Калинино',
#  'Канаш',
#  'Карабай-Шемурша',
#  'Карабаши',
#  'Карамышево (Чувашская Республика)',
#  'Кильдюшево',
#  'Киря',
#  'Климово (Чувашская Республика)',
#  'Ковали',
#  'Кожары',
#  'Козловка',
#  'Комсомолец (Чувашская Республика)',
#  'Комсомольское (Чувашская Республика)',
#  'Конар',
#  'Кошноруй',
#  'Красноармейское',
#  'Красные Четаи',
#  'Кувакино',
#  'Кугеси',
#  'Лащ-Таяба',
#  'Малая Таяба',
#  'Малое Янгорчино',
#  'Мариинский Посад',
#  'Междуречье (Чувашская Республика)',
#  'Можарки',
#  'Моргауши',
#  'Напольные Котяки',
#  'Нижние Мочары',
#  'Николаевское',
#  'Шимкусы',
#  'Никулино',
#  'Новое Атлашево',
#  'Новочебоксарск',
#  'Новочелны-Сюрбеево',
#  'Новые Лапсары',
#  'Новые Мураты',
#  'Новые Шальтямы',
#  'Новые Шимкусы',
#  'Пандиково',
#  'Первое Чурашево',
#  'Первомайское (Чувашская Республика)',
#  'Пикшики',
#  'Полевые Бикшики',
#  'Порецкое',
#  'Сабанчино',
#  'Синьялы',
#  'Советское (Чувашская Республика)',
#  'Солдыбаево',
#  'Средние Кибечи',
#  'Старые Атаи',
#  'Старые Тиньгеши',
#  'Старые Чукалы',
#  'Стемасы',
#  'Сугуты',
#  'Тарханы',
#  'Тобурданово',
#  'Тойси',
#  'Торханы',
#  'Трехбалтаево',
#  'Тувси',
#  'Тузи-Сярмус',
#  'Турмыши',
#  'Тюмерево',
#  'Тюрлема',
#  'Урмары',
#  'Ходары',
#  'Хыркасы',
#  'Цивильск',
#  'Чадукасы',
#  'Чебоксары',
#  'Челкасы',
#  'Чепкас-Никольское',
#  'Чувашские Тимяши',
#  'Чурачики',
#  'Чутеево',
#  'Шемалаково',
#  'Шемурша',
#  'Шерауты',
#  'Шибылги',
#  'Шигали',
#  'Шихазаны',
#  'Шоркистры',
#  'Шоршелы',
#  'Шумерля',
#  'Шумшеваши',
#  'Шыгырдан',
#  'Эльбарусово',
#  'Юнга',
#  'Юськасы',
#  'Ядрин',
#  'Яльчики',
#  'Янгличи',
#  'Янгорчино',
#  'Янтиково',
#  'Яншихово-Норваши',
#  'Яншихово-Челлы',
#  'Яныши',
#  'Ярославка',
#  'Забайкальский край',
#  'Ага (Забайкальский край)',
#  'Ага-Хангил (Забайкальский край)',
#  'Агинское (Забайкальский АО)',
#  'Адриановка (Забайкальский край)',
#  'Аксеново-Зиловское (Забайкальский край)',
#  'Акша (Забайкальский край)',
#  'Александровский Завод',
#  'Алеур (Забайкальский край)',
#  'Алханай (Забайкальский край)',
#  'Альбитуй',
#  'Амазар',
#  'Амитхаша (Забайкальский край)',
#  'Атамановка (Читинский район)',
#  'Бада',
#  'Балей',
#  'Баляга',
#  'Беклемишево (Забайкальский край)',
#  'Билитуй (Забайкальский край)',
#  'Большая Тура (Забайкальский край)',
#  'Боржигантай (Забайкальский край)',
#  'Борзя',
#  'Букачача',
#  'Бырка (Забайкальский край)',
#  'Верх-Усугли',
#  'Верх-Чита',
#  'Вершино-Дарасунский',
#  'Вершино-Шахтаминский (Забайкальский край)',
#  'Вершино-Шахтаминское',
#  'Газимурский Завод',
#  'Горный (Забайкальский край)',
#  'Горный Зерентуй (Забайкальский край)',
#  'Гунэй (Забайкальский край)',
#  'Давенда',
#  'Дарасун (Забайкальский край)',
#  'Даурия (Забайкальский край)',
#  'Домна (Забайкальский край)',
#  'Досатуй',
#  'Дровяная',
#  'Дульдурга',
#  'Дунаево (Забайкальский край)',
#  'Жиндо',
#  'Жипхеген',
#  'Жирекен',
#  'Забайкальск',
#  'Засопка (Забайкальский край)',
#  'Золотореченск',
#  'Зугалай (Забайкальский край)',
#  'Зуткулей (Забайкальский край)',
#  'Зюльзя (Забайкальский край)',
#  'Ингода (Забайкальский край)',
#  'Кадахта (Забайкальский край)',
#  'Кадая',
#  'Казаново (Забайкальский край)',
#  'Калангуй (Забайкальский край)',
#  'Калга',
#  'Карымское',
#  'Кличка',
#  'Ключевский',
#  'Ковыли (Забайкальский край)',
#  'Шишкино (Забайкальский край)',
#  'Кокуй (Забайкальский край)',
#  'Краснокаменск',
#  'Красный Чикой',
#  'Ксеньевка',
#  'Куанда',
#  'Кункур (Забайкальский край)',
#  'Курорт-Дарасун',
#  'Кусоча (Забайкальский край)',
#  'Кыра',
#  'Лесной Городок (Забайкальский край)',
#  'Линево Озеро (Забайкальский край)',
#  'Маккавеево',
#  'Малета',
#  'Мангут',
#  'Маргуцек (Забайкальский край)',
#  'Мирная (Забайкальский край)',
#  'Могзон (Забайкальский край)',
#  'Могойтуй',
#  'Могоча',
#  'Молодежный (Забайкальский край)',
#  'Нерчинск',
#  'Нерчинский Завод',
#  'Нижний Цасучей',
#  'Николаевское (Забайкальский край)',
#  'Новая Кука',
#  'Новая Чара',
#  'Новокручининский',
#  'Новоорловск',
#  'Новопавловка',
#  'Новоцурухайтуй (Забайкальский край)',
#  'Новоширокинский',
#  'Оловянная',
#  'Ононское (Забайкальский край)',
#  'Орловский (Забайкальский край)',
#  'Ортуй (Забайкальский край)',
#  'Первомайский (Забайкальский край)',
#  'Петровск-Забайкальский',
#  'Приаргунск',
#  'Приисковый (Забайкальский край)',
#  'Сахюрта (Забайкальский край)',
#  'Сбега',
#  'Семиозерный (Забайкальский край)',
#  'Смоленка (Забайкальский край)',
#  'Сохондо (Забайкальский край)',
#  'Сретенск',
#  'Степь (Забайкальский край)',
#  'Судунтуй (Забайкальский край)',
#  'Тарбагатай (Забайкальский край)',
#  'Токчин (Забайкальский край)',
#  'Тупик',
#  'Тыргетуй (Забайкальский край)',
#  'Угдан (Забайкальский край)',
#  'Узон (Забайкальский край)',
#  'Улёты',
#  'Ундино-Поселье (Забайкальский край)',
#  'Урда-Ага (Забайкальский край)',
#  'Урлук',
#  'Урульга',
#  'Усть-Карск',
#  'Утан (Забайкальский край)',
#  'Ушарбай (Забайкальский край)',
#  'Хада-Булак (Забайкальский край)',
#  'Харагун (Забайкальский край)',
#  'Харанор (Забайкальский край)',
#  'Хара-Шибирь (Забайкальский край)',
#  'Хилок',
#  'Холбон',
#  'Хохотуй',
#  'Хушенга (Забайкальский край)',
#  'Цаган-Ола (Забайкальский край)',
#  'Цаган-Челутай (Забайкальский край)',
#  'Целинный (Забайкальский край)',
#  'Цокто-Хангил (Забайкальский край)',
#  'Чара',
#  'Чернышевск',
#  'Чиндалей (Забайкальский край)',
#  'Чита',
#  'Шара-Горохон (Забайкальский край)',
#  'Шелопугино (Забайкальский край)',
#  'Шерловая Гора',
#  'Шилка',
#  'Широкая',
#  'Ягодный (Забайкальский край)',
#  'Ясная (Забайкальский край)',
#  'Ясногорск (Забайкальский край)',
#  'Иркутская область',
#  'Азей',
#  'Алгатуй',
#  'Алексеевск',
#  'Алзамай',
#  'Ангарск',
#  'Артемовский (Иркутская область)',
#  'Бадар',
#  'Байкальск',
#  'Балаганск',
#  'Балахнинский',
#  'Баяндай',
#  'Белореченский',
#  'Березняки',
#  'Бирюсинск',
#  'Бодайбо',
#  'Большая Речка',
#  'Большой Луг',
#  'Бохан',
#  'Братск',
#  'Будагово',
#  'Введенщина',
#  'Верхнемарково',
#  'Видим',
#  'Вихоревка',
#  'Гидростроитель',
#  'Гуран',
#  'Еланцы',
#  'Ербогачен',
#  'Железногорск-Илимский',
#  'Железнодорожный (Иркутская область)',
#  'Жигалово',
#  'Забитуй',
#  'Залари',
#  'Зима',
#  'Икей',
#  'Иркутск',
#  'Каразей',
#  'Карымск',
#  'Качуг',
#  'Квиток',
#  'Кимильтей',
#  'Киренск',
#  'Куйтун',
#  'Култук',
#  'Кундуй',
#  'Кутулик',
#  'Лесогорск',
#  'Листвянка',
#  'Магистральный',
#  'Мама',
#  'Мамакан',
#  'Маркова',
#  'Мегет',
#  'Михайловка (Иркутская область)',
#  'Мишелевка',
#  'Нижнеудинск',
#  'Новая Игирма',
#  'Новобирюсинский',
#  'Новонукутский',
#  'Баклаши',
#  'Оек',
#  'Октябрьский (Иркутская область)',
#  'Олонки',
#  'Ольхон',
#  'Оса (Иркутская область)',
#  'Покосное',
#  'Речушка',
#  'Рудногорск',
#  'Саянск',
#  'Свирск',
#  'Седаново',
#  'Слюдянка',
#  'Смоленщина',
#  'Средний',
#  'Тайтурка',
#  'Тайшет',
#  'Тангуй',
#  'Тельма',
#  'Тубинский',
#  'Тулун',
#  'Тулюшка',
#  'Тыреть 1-я',
#  'Ук',
#  'Улькан',
#  'Усолье-Сибирское',
#  'Усть-Илимск',
#  'Усть-Кут',
#  'Усть-Ордынский',
#  'Усть-Уда',
#  'Уян',
#  'Харик',
#  'Хомутово (Иркутская область)',
#  'Черемушки',
#  'Черемхово',
#  'Чунский',
#  'Шелехов',
#  'Шелехово',
#  'Шиткино',
#  'Шумский',
#  'Эдучанка',
#  'Юрты',
#  'Янталь',
#  'Красноярский край',
#  'Абалаково',
#  'Абан',
#  'Агинское',
#  'Ангарский',
#  'Артемовск (Красноярский край)',
#  'Ачинск',
#  'Байкит',
#  'Балахта (Красноярский край)',
#  'Беллык',
#  'Березовка (Красноярский край)',
#  'Березовское',
#  'Боготол',
#  'Богучаны',
#  'Большая Иня',
#  'Большая Ирба',
#  'Большая Мурта',
#  'Большая Уря',
#  'Большой Улуй',
#  'Бородино',
#  'Бражное',
#  'Брянка (Красноярский край)',
#  'Ванавара',
#  'Вангаш',
#  'Волочанка',
#  'Галанино',
#  'Георгиевка',
#  'Детлово',
#  'Дзержинское',
#  'Дивногорск',
#  'Диксон',
#  'Долгий Мост',
#  'Дрокино',
#  'Дубинино',
#  'Дудинка (Красноярский край)',
#  'Емельяново',
#  'Енисейск',
#  'Ермаковское',
#  'Железногорск (Красноярский край)',
#  'Заозерный',
#  'Зеленогорск (Красноярский край)',
#  'Зеленый Бор',
#  'Златоруновск',
#  'Зыково',
#  'Игарка',
#  'Идринское',
#  'Иланский',
#  'Ильичево',
#  'Инголь',
#  'Ирбейское',
#  'Казачинское',
#  'Кайеркан',
#  'Канск',
#  'Каптырево',
#  'Каратузское',
#  'Кедровый (Красноярский край)',
#  'Кодинск',
#  'Кожаны',
#  'Козулька',
#  'Кордово',
#  'Каштан',
#  'Кортуз',
#  'Кошурниково',
#  'Красная Сопка',
#  'Красногорьевский',
#  'Краснокаменск (Красноярский край)',
#  'Краснотуранск',
#  'Красноярск',
#  'Курагино',
#  'Лесосибирск',
#  'Лугавское',
#  'Манзя',
#  'Маринино',
#  'Машуковка',
#  'Мессояха',
#  'Миндерла',
#  'Минино (Мининский сельсовет)',
#  'Минусинск',
#  'Момотово',
#  'Мотыгино',
#  'Назарово',
#  'Нижний Ингаш',
#  'Нижняя Пойма',
#  'Новая Солянка',
#  'Новоангарск',
#  'Новобирилюссы',
#  'Новокаргино',
#  'Новопятницкое',
#  'Новосёлово',
#  'Новочернореченский',
#  'Норильск',
#  'Октябрьский (Красноярский край)',
#  'Орджоникидзе (Красноярский край)',
#  'Осиновый Мыс',
#  'Памяти 13 Борцов',
#  'Парная',
#  'Партизанское',
#  'Первомайск (Красноярский край)',
#  'Пинчуга',
#  'Пировское',
#  'Подгорный',
#  'Подтесово',
#  'Потапово',
#  'Предивинск',
#  'Раздолинск',
#  'Российка',
#  'Саянский',
#  'Светлогорск (Красноярский край)',
#  'Северо-Енисейский (Красноярский край)',
#  'Сизая',
#  'Снежногорск (Красноярский край)',
#  'Солнечный (Красноярский край)',
#  'Сосновоборск',
#  'Субботино',
#  'Сухобузимское',
#  'Таежный',
#  'Тасеево',
#  'Тесь',
#  'Тинской',
#  'Тура (Красноярский край)',
#  'Туруханск',
#  'Тюльково',
#  'Тюхтет',
#  'Ужур',
#  'Урал',
#  'Усть-Кемь',
#  'Устьянск',
#  'Уяр',
#  'Филимоново',
#  'Хантайское Озеро',
#  'Хатанга',
#  'Черемшанка',
#  'Чунояр',
#  'Шалинское',
#  'Шалоболино',
#  'Шарыпово',
#  'Шушенское',
#  'Элита',
#  'Южно-Енисейск',
#  'Республика Бурятия',
#  'Ангоя',
#  'Аршан (Бурятия)',
#  'Бабушкин',
#  'Багдарин',
#  'Баргузин',
#  'Баянгол',
#  'Бичура',
#  'Выдрино',
#  'Горхон',
#  'Горячинск',
#  'Гусиное Озеро',
#  'Гусиноозерск',
#  'Джида',
#  'Заиграево',
#  'Закаменск',
#  'Иволгинск',
#  'Ильинка',
#  'Илька',
#  'Итанца',
#  'Кабанск',
#  'Каменск',
#  'Кижинга',
#  'Кичера',
#  'Кома',
#  'Кудара',
#  'Кудара-Сомон',
#  'Куйтун (Республика Бурятия)',
#  'Курумкан',
#  'Кырен',
#  'Кяхта',
#  'Мухоршибирь',
#  'Наушки',
#  'Нижнеангарск',
#  'Нижний Торей',
#  'Никольск',
#  'Новая Брянь',
#  'Новоильинск',
#  'Новоселенгинск',
#  'Новый Уоян',
#  'Онохой',
#  'Орлик',
#  'Петропавловка (Республика Бурятия)',
#  'Подлопатки',
#  'Саган-Нур',
#  'Северобайкальск',
#  'Северомуйск',
#  'Селенгинск',
#  'Селендум',
#  'Сосново-Озерское',
#  'Таксимо',
#  'Таловка',
#  'Тарбагатай',
#  'Татарский Ключ',
#  'Татаурово',
#  'Тугнуй',
#  'Турунтаево',
#  'Улан-Удэ',
#  'Унэгэтэй',
#  'Усть-Баргузин',
#  'Хонхолой',
#  'Хоринск',
#  'Хоронхой',
#  'Цолга',
#  'Шарагол',
#  'Шаралдай',
#  'Янчукан',
#  'Республика Саха (Якутия)',
#  'Абага',
#  'Айхал',
#  'Алдан',
#  'Алмазный',
#  'Амга',
#  'Аргахтах',
#  'Батагай',
#  'Батагай-Алыта',
#  'Бердигестях',
#  'Беркакит',
#  'Бестях',
#  'Болугур',
#  'Борогонцы',
#  'Верхневилюйск',
#  'Верхний Куранах',
#  'Верхоянск',
#  'Вилюйск',
#  'Витим',
#  'Депутатский',
#  'Джебарики-Хая',
#  'Жатай',
#  'Жиганск',
#  'Зырянка',
#  'Иенгра',
#  'Казачье',
#  'Кангалассы',
#  'Кемпендяй',
#  'Кобяй',
#  'Кутана',
#  'Кысыл-Сыр',
#  'Кюндяде',
#  'Кюндядя',
#  'Кюсюр',
#  'Лебединый',
#  'Ленинский (Республика Саха (Якутия))',
#  'Ленск',
#  'Майя',
#  'Малыкай',
#  'Мар',
#  'Мирный (Республика Саха (Якутия))',
#  'Мохсоголлох',
#  'Намцы',
#  'Нерюнгри',
#  'Нижнеянск',
#  'Нижний Бестях',
#  'Нижний Куранах',
#  'Нюрба',
#  'Нюя',
#  'Огородтах',
#  'Октемцы',
#  'Олекминск',
#  'Оленек',
#  'Пеледуй',
#  'Покровск (Якутия)',
#  'Сангар',
#  'Саскылах',
#  'Сасыр',
#  'Сватай',
#  'Солнечный (Якутия)',
#  'Среднеколымск',
#  'Белая Гора',
#  'Сунтар',
#  'Сылгы-Ыытар',
#  'Тёплый Ключ (Республика Саха)',
#  'Тербяс',
#  'Тикси',
#  'Тойбохой',
#  'Томмот',
#  'Томтор',
#  'Тополиное',
#  'Тосу',
#  'Тюнгюлю',
#  'Удачный',
#  'Усть-Куйга',
#  'Усть-Мая',
#  'Усть-Миль',
#  'Усть-Нера',
#  'Усун',
#  'Хандыга',
#  'Харбалах',
#  'Хатын-Сысы',
#  'Хонуу',
#  'Чернышевский (Республика Саха (Якутия))',
#  'Черский',
#  'Чинеке',
#  'Чокурдах',
#  'Чульман',
#  'Чурапча',
#  'Шея',
#  'Ытык-Кюель',
#  'Эбях',
#  'Эльгяй',
#  'Эльдикан',
#  'Якутск',
#  'Республика Тыва',
#  'Ак-Довурак',
#  'Бай-Хаак',
#  'Каа-Хем',
#  'Кызыл',
#  'Кызыл-Мажалык',
#  'Самагалтай',
#  'Сарыг-Сеп',
#  'Тоора-Хем',
#  'Туран',
#  ...]
